# %% [markdown]
# <a href="https://colab.research.google.com/github/Sancocho-VIII/Deber-3-Teoria-de-Python/blob/main/examen_juego_Emilio_Sanchez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def tablero():
  tablero={1:'_|1|_', 2:'_|2|_',3:'_|3|_',4:'_|4|_',5:'_|5|_',6:'_|6|_',7:'_|7|_',8:'_|8|_',9:'_|9|_'}
  return f"{tablero[1]}{tablero[2]}{tablero[3]}\n{tablero[4]}{tablero[5]}{tablero[6]}\n{tablero[7]}{tablero[8]}{tablero[9]}"

# %%
class Jugador:
  def __init__(self, nombre, simbolo):
    self.nombre=nombre
    self.simbolo=simbolo
  def jugada(self):
    pos=int(input("Elije una casilla "))
    tablero[pos-1]={self.simbolo}
    return tablero

# %%
paul = 1
tab=tablero()
print(tab)
jug1=input("Nombre jugador 1: ")
jug2=input("Nombre jugador 2: ")
jugador1 = Jugador(ejug1,"X")
jugador2= Jugador(jug2, "O")
while paul==1:
  jugador1.jugada()
  jugador2.jugada()
# Out:
# _|1|__|2|__|3|_
# _|4|__|5|__|6|_
# _|7|__|8|__|9|_
# Nombre jugador 1: alalou
# Nombre jugador 2: etoile
# Elije una casilla 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_32447/2392017963.py in <cell line: 0>()
#       7 jugador2= Jugador(jug2, "O")
#       8 while paul==1:
# ----> 9   jugador1.jugada()
#      10   jugador2.jugada()
#      11
#
# /tmp/ipykernel_32447/2703707293.py in jugada(self)
#       5   def jugada(self):
#       6     pos=int(input("Elije una casilla "))
# ----> 7     tablero[pos-1]={self.simbolo}
#       8     return tablero
#       9
#
# TypeError: 'function' object does not support item assignment
